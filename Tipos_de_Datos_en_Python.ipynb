# %% [markdown]
# <a href="https://colab.research.google.com/github/LCaravaggio/EscueladeInnovacion/blob/main/Tipos_de_Datos_en_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tipos de Datos en Python

# %% [markdown]
# ![6cg2E9Q.png](data:image/png;base64,...)

# %% [markdown]
# ## Integer

# %%
entero=1

# %%
entero
# Out:
# 1

# %%
entero+1
# Out:
# 2

# %%
type(entero)
# Out:
# int

# %% [markdown]
# # Float

# %%
pi = 3.141592653589793238
pi
# Out:
# 3.141592653589793

# %%
type(pi)
# Out:
# float

# %% [markdown]
# # Boolean

# %%
flag=False

# %%
flag=True

# %%
if flag==False:
  print('Es false')
else:
  print('Es true')
# Out:
# Es true

# %%
type(flag)
# Out:
# bool

# %% [markdown]
# # None

# %%
nothing = None
type(nothing)
# Out:
# NoneType

# %% [markdown]
# # String

# %%
hoy='Domingo'

# %%
hoy
# Out:
# 'Domingo'

# %%
type(hoy)
# Out:
# str

# %%
len(hoy)
# Out:
# 7

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
hoy[3]
# Out:
# 'i'

# %%
hoy[:3]
# Out:
# 'Dom'

# %%
hoy[2:]
# Out:
# 'mingo'

# %%
'Hoy es ' + hoy
# Out:
# 'Hoy es Domingo'

# %%
hoy.upper()
# Out:
# 'DOMINGO'

# %%
hoy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-90b9bf5890fc> in <cell line: 1>()
# ----> 1 hoy
#
# NameError: name 'hoy' is not defined

# %%
hoy.lower()
# Out:
# 'domingo'

# %% [markdown]
# # Lista

# %%
frutas=['Pera', 'Manzana', 'Banana']

# %%
frutas2=list(['Pera', 'Manzana', 'Banana'])

# %%
frutas2
# Out:
# ['Pera', 'Manzana', 'Banana']

# %%
type(frutas2)
# Out:
# list

# %%
type(frutas)
# Out:
# list

# %%
frutas[1]='Naranja'

# %%
frutas
# Out:
# ['Pera', 'Naranja', 'Banana']

# %%
otra_lista=['Pera', 'Domingo', 1, 3.14, None, False]

# %%
type(otra_lista)
# Out:
# list

# %%
len(otra_lista)
# Out:
# 6

# %%
len(frutas)
# Out:
# 3

# %%
otra_lista[3]
# Out:
# 3.14

# %%
otra_lista[:3]
# Out:
# ['Pera', 'Domingo', 1]

# %% [markdown]
# # Tuple

# %%
frutas=('Pera', 'Manzana', 'Banana')

# %%
frutas2=tuple(['Peras', 'Manzana'])

# %%
type(frutas2)
# Out:
# tuple

# %%
type(frutas)
# Out:
# tuple

# %%
frutas[1]
# Out:
# 'Manzana'

# %%
frutas[1]='Mango'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-1b51648dbdfb> in <cell line: 1>()
# ----> 1 frutas[1]='Mango'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Dictionary

# %%
person1 = {
    'name': 'John Doe',
    'sex': 'Male',
    'age': 32,
    'married': True
}

# %%
person2 = dict(name='Jane Judy', sex='Female', age=28, married=False, city='New York')

# %%
person1['name']
# Out:
# 'John Doe'

# %%
person2['city']
# Out:
# 'New York'

# %%
person1['city']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-6b76bb58256e> in <cell line: 1>()
# ----> 1 person1['city']
#
# KeyError: 'city'
